# %%
import pandas as pd
import matplotlib.pyplot as plt
import wordcloud

# %%
traffic_accident=pd.read_csv("\\traffic\\accident_data.csv",encoding='utf-8')
unnamed=["Unnamed: "+str(i) for i in range(21,50) ]
print(unnamed)
traffic_accident=traffic_accident.drop(unnamed,axis=1)
# Out:
# ['Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49']
# E:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(traffic_accident.columns)
print(traffic_accident.head(5))
print(traffic_accident)
# Out:
# Index(['﻿accidenttime', 'accidentaddr', 'driver1fault',
#        'driver1responsibility', 'driver2responsibility', 'sex1',
#        'platenumber1', 'carcolor1', 'sex2', 'platenumber2', 'carcolor2',
#        'jxmc1', 'jxmc2', 'cclzrq1', 'cclzrq2', 'clpp1', 'clpp2',
#        'driver1license', 'driver2license', 'brith1', 'brith2'],
#       dtype='object')
#          ﻿accidenttime accidentaddr             driver1fault  \
# 0  2015-01-02 04:20:00          白云区  9、不符合前8款规定或者双方同时具有上述情形的
# 1  2015-01-05 17:05:00          北二环                    1、追尾的
# 2  2015-01-05 17:30:00        兴关路路口               7、未按规定让行的
# 3  2015-01-06 15:05:00           阳关            8、依法应负全责的其他情形
# 4  2015-01-07 00:00:00          望城坡               7、未按规定让行的
#
#   driver1responsibility driver2responsibility  sex1 platenumber1 carcolor1  \
# 0                 负同等责任                 负同等责任     1      贵AU2906         黑
# 1                 负全部责任                  不负责任     1      贵A7160F         红
# ...

# %%
weather=pd.read_csv("\\traffic\\weather_data.csv",encoding='utf-8')
print(weather.columns)
print(weather.head(5))
# Out:
# Index(['﻿日期', '天气状况', '气温', '风力风向'], dtype='object')
#          ﻿日期    天气状况        气温              风力风向
# 0  2015年1月1日    阴 /阴   8℃ / 6℃   东北风 ≤3级 /南风 ≤3级
# 1  2015年1月2日  多云 /多云  12℃ / 6℃    南风 ≤3级 /南风 ≤3级
# 2  2015年1月3日  多云 /多云  13℃ / 7℃    南风 ≤3级 /南风 ≤3级
# 3  2015年1月4日   多云 /阴  13℃ / 7℃  东北风 ≤3级 /东南风 ≤3级
# 4  2015年1月5日  小雨 /小雨  11℃ / 3℃  东南风 ≤3级 /东北风 ≤3级

# %%
illegl_data=pd.read_csv("illegal_data.csv",encoding='utf-8')
unnamed=["Unnamed: "+str(i) for i in range(6,13) ]
illegl_data=illegl_data.drop(unnamed,axis=1)
print(illegl_data)
# Out:
#                     ﻿jsz8                    wfbh                 wfsj   wfxw  \
# 0      366875518241534519  5201112015111811669521  2015-11-05 10:23:00  60230
# 1      36606851984051445X  5201112015111811670071  2015-10-23 13:48:00  60230
# 2      364555519243484051  5201112015111811670581  2015-10-27 16:09:00  60230
# 3      364555519454427458  5201112015111811670611  2015-10-27 16:15:00  60230
# 4      364556519841456672  5201112015111811671151  2015-11-16 13:22:00  60230
# 5      364555519440495370  5201112015111811672311  2015-10-28 13:06:00  60230
# 6      366576511449406551  5201112015111811672431  2015-10-28 13:33:00  50382
# 7      366576511454556673  5201112015111811673261  2015-10-29 15:14:00  60230
# 8      366875519055746453  5201112015111811673511  2015-11-09 15:31:00  60230
# 9      366569511549635330  5201112015111811684571  2015-10-30 11:07:00  10480
# 10     366066519056495485  5201112015111811684901  2015-10-30 14:29:00  10480
# ...

# %%
traffic_accident.to_csv("traffic_accident_data.csv",encoding='utf-8')

# %%
illegl_data.to_csv("illegal_data.csv",encoding='utf-8')
